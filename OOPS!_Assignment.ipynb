# %% [markdown]
# #**OOPS**

# %% [markdown]
# #1. What is Object-Oriented Programming (OOP)?
# It is a way of writing code, that organizes the software design around objects, and not functions and logic.
# * Example-
# 1. Class - Blue print of a Car(brand, model, color)
# 2. Object - Actual cars(toyota, Tesla)
#
# #2. What is a class in OOP?
# A class is a blueprint or template in OOPS that defines- Attributes and Methods.
# * Attributes- properties of the object
# * Methods - behaviour of the object

# %%
# Example-
class Student:
  def __init__(self,name,age): # attributes
    self.name = name
    self.age = age
  def display(self):
    print(f"Name : {self.name}, Age : {self.age}")

s1 = Student("Priyanka", 26) # creating objects
s1.display()
# Out:
# Name : Priyanka, Age : 26

# %% [markdown]
# #3. What is object in OOP?
# An object is an instance of the class. Attributes are object's state and methods are object's behaviour.

# %%
class Dog: # DOG IS THE CLASS
  def __init__(self,name):
    self.name = name

  def bark(self):
    print(self.name, "is barking")

dog1 = Dog("Tommy") # dog1 and dog2 are objects- both can bark(same action)
dog2 = Dog("Chikoo")

dog1.bark()
dog2.bark()
# Out:
# Tommy is barking
# Chikoo is barking

# %% [markdown]
# #4. What is the difference between abstraction and encapsulation?
#
# * Abstraction -
# 1. Hiding the implimentation details and showing only the essential features.
# 2. It focuses on what the object does and not how the object does
# 3. Eg - While driving a car, we only see the steering, the breaks. The mechanism of how the machine works is abstracted from us.
#
# * Encapsulation-
# 1. Wrapping the variables and the fumction into a single unit
# 2. Focuses on how data and methods are bound together.
# 3. Eg - We cannot directly access the engine mechanism. We can only use it via controlled methods

# %%
# Abstraction example
from abc import ABC, abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius
  def area(self):
    return 3.14 * self.radius * self.radius

c = Circle(10)
c.area()
# Out:
# 314.0

# %%
#  Encapsulation
class Account:
  def __init__(self, balance):
    self.balance = balance

  def deposit(self, amount):
    self.balance += amount

  def get_balance(self):
    return self.balance

acc = Account(10000000)
acc.deposit(9000)
acc.get_balance()
# Out:
# 10009000

# %% [markdown]
# #5. What are dunder methods in Python?
#
# Dunder methods are special methods in python, whose names start and end with double underscore (__)
#
# "Dunder" stands for Double UNDERscore. They are also known as magic methods.
# __init__ when an object is created
#
# #6. Explain the concept of inheritance in OOP?
#  Here the child class can reuse the properties and methods of a parent class. The parent class, whose features are inherited, and child class, that inherits the parent.
# For eg - In class animal("that makes sound"), dog inherits traits of the animal as dog - barks
#
# #7. What is polymorphism in OOP?
#
# Polymorphism allows the same function name or operator to behave differently, depending on the object data or type. Example - The word 'run' has many forms i.e; the person 'runs' fast, a prog 'runs' on computer.
#
# #8. How is encapsulation achieved in Python?
#
# Encapsulation is the principle of binding attributes and functions in a single unit, and restricting the access to some of the objects components. There are three type of attributes, Public, Protected and Private. Public- can be accessed, Private - intended for internal use, Private - cannot be accessed directly.
#
# #9. What is a constructor in Python?
#
# A constructor is a special method in a class, that is automatically called when an object is created. Its main pupose is to initialize the object's attributes by __init__ (dunder method).
# If we dont define a constructor python does nothing.
#
# #10. What are class and static methods in Python?
#
# * Class - class methods , operate on the class itself, not on the individual object. It is defined using @classmethod
#
# * Static - methods do not access class (cls) or object (self) attributes. It is defined using @staticmethod
#
# #11. What is method overloading in Python?
#
#  Method overloading means defining multiple methods with the same name, but different parameters. Its simulation is don e by *args/ *kwargs.
#
#  #12. What is method overriding in OOP?
#
# Method overriding occurs when a child class provides itw own implementation of a method, that already exist in parent class.It is used for run time poly morphism in OOP.
#
#
# #13. What is a property decorator in Python?
# The @property decorator allows you to define methods in a class that can be accessed like attributes. It is used to encapsulate attributes but access like a normal variable.
# It controls access to private attributes.
#
# #14. Why is polymorphism important in OOP?
#
# Polymorphism means "**many forms**"- which uses the same interface in different ways depending on the object.
# Same method name works for different objects and reduces the need to write multiple method names for similar behaviour.
# It can be maintained, as new classes do not require changing existing code.
#
#
# #15.  What is an abstract class in Python?
#
# Abstract class is a class that cannot be instantiated, and is inherited by other class.
# It can contain abstract methods and regular methods.
# Abstract methods must be implimented in the child class.Abstract class is blue print of other class and are declared by using @abstractmethod.
#
# #16. What are the advantages of OOP?
# * We can reuse existing classes through inheritence, it reduces duplication and saves time.
# * OOP bundles data and methods together and cann hide internal detaiols by the method - encapsulation.
# * same method or operator can behave differently depending on the object.
# * it allows you to model, real world entities with attributes and behaviours.
#
# #17. What is the difference between a class variable and an instance variable?
#
# * Class variable -
# 1. It is shared across all objects of the class
# 2. It can be accessed by the class or object
# 3. Any change i it affects all the objects.
#
# * Instance variable -
# 1. It is unique to each object
# 2. It is stored seperately for each object
# 3. Its change, affects only that object.
#
# #18. What is multiple inheritance in Python?
#
# Multiple inheritence means that a child class can inherit from more than one parent class.
# A class can inherit multiple base classes by listing them in parenthesis.
#  Eg - class Child(Parent1,Parent2, Parent3)
#
#
# #19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
#
# They are special methods cvalled Dunder Methods, that control how objects are represented as strings
# __str__ returns a readable, user freindly string of the object.
#
# __repr__ it returns a detailed, unambiguous string that helps developers understand the object.
# It is meant to return a string, that can be used to recreate an object.
#
#
# #20. What is the significance of the ‘super()’ function in Python?
#
# The super() function is used to call methods from aparent class(super class) in a child class(sub class). It avoids code duplication, as we dont have to rewrite the parent logic in the child class. And it makes the code more compatible and scalable.
#
# #21. What is the significance of the __del__ method in Python?
#
# The __del__ method is a destructor method. It is called when an object is about to be destroyed. We dont call it directly, python's garbage collector calls it when the object is no longer needed.
#
# #22. What is the difference between @staticmethod and @classmethod in Python?
#
# @staticmethod - does not depend on the class. It works like a normal function, but is placed inside a class for logical grouping.
#
# @classmethod -a method that works with the class itself and not the instance. Takes cls as the first argument instead of self.
#
# #23.  How does polymorphism work in Python with inheritance?
#
# Polymorphism with inheritence allows the child class to provide different implimentation of a method that is already defined in parent class.
#
# A parent class defines a method. One or more child class overrides the method. And when we call the method on the child object, the child's version is executed, even if the reference is of the parent type.
#
#
# #24. What is method chaining in Python OOP?
#
# Method changing, means calling multiple methods on the same object, on the same line. Inside each method of a class, return self.
#
# #25. What is the purpose of the __call__ method in Python?
#
# The __call__ method is a special dunder method that lets an object behave like a function. If a class defines __call__ then its instances can be "called" using (). ALso it helps in encapsulation.

# %% [markdown]
# #**Practical QS**

# %% [markdown]
# #1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:
  def speak(self):
    print("Animal makes sound")

class Dog(Animal):
  def speak(self):
    print("Dog Barks!")

dog = Dog()
dog.speak()
# Out:
# Dog Barks!

# %% [markdown]
# #2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def area(self):
    return 3.14 * self.radius * self.radius

class Rectangle(Shape):
  def __init__(self, length, width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width

shapes = [Circle(21) , Rectangle( 10,8)]

for shape in shapes:
  print(shape.area())
# Out:
# 1384.74
# 80

# %% [markdown]
# #3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
  def __init__(self, type):
    self.type = type

class Car(Vehicle):
  def __init__(self, type, brand):
    super().__init__(type)
    self.brand = brand

class ElectricCar(Vehicle):
  def __init__(self, type, brand, battery):
    super().__init__(type, brand)
    self.battery = battery

obj1 = Vehicle("Modular")
obj1.type
# Out:
# 'Modular'

# %%
obj2 = Car("Modular", "Toyota")
obj2.brand
# Out:
# 'Toyota'

# %%
obj3 = ElectricCar("Modular", "Toyota", "Advanced")
obj3.battery
# Out:
# 'Advanced'

# %% [markdown]
# #4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:
  def fly(self):
    print("Bird's can fly")

class Sparrow(Bird):
  def fly(self):
    print("Sparrow can fly high")

class Penguin(Bird):
  def fly(self):
    print("Penguin can't fly")

bird = Bird()
bird.fly()
# Out:
# Bird's can fly

# %%
bird1 = Sparrow()
bird1.fly()
# Out:
# Sparrow can fly high

# %%
bird2 = Penguin()
bird2.fly()
# Out:
# Penguin can't fly

# %% [markdown]
# #5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
  def __init__(self, balance = 0):
    self.__balance = balance

  def deposit(self, amount):
    self.__balance += amount
    print(f"Deposited : {amount}")


  def withdraw(self, amount):
    if amount <= self.__balance:
      self.__balance -= amount
      print(f"Withdraw : {amount}")
    else :
      print("Insufficient balance")

  def show_balance(self):
    print(f"Balance : {self.__balance}")


account = BankAccount(90000)
account.deposit(100000)
account.withdraw(5000)
account.show_balance()
# Out:
# Deposited : 100000
# Withdraw : 5000
# Balance : 185000

# %% [markdown]
# #6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
  def play(self):
    print("Instrument's are played")

class Guitar(Instrument):
  def play(self):
    print("Guitar is played using strings")

class Piano(Instrument):
  def play(self):
    print("Piano is played using keys")


inst = Instrument()
inst.play()
# Out:
# Instrument's are played

# %%
inst1 = Guitar()
inst1.play()
# Out:
# Guitar is played using strings

# %%
inst2 = Piano()
inst2.play()
# Out:
# Piano is played using keys

# %% [markdown]
# #7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOps:
  @classmethod
  def add_numbers(cls, a, b):
    return a + b

  @staticmethod
  def subtract_numbers(a,b):
    return a - b

sum_result = MathOps.add_numbers(10,15)
print(sum_result)

diff_result = MathOps.subtract_numbers(20,10)
print(diff_result)
# Out:
# 25
# 10

# %% [markdown]
# #8.  Implement a class Person with a class method to count the total number of persons created

# %%
class Person:
  count = 0

  def __init__(self, name):
    self.name = name
    Person.count += 1

  @classmethod
  def total_person(cls):
    return cls.count

p1 = Person("Priyanka")
p2 = Person("Virat")
p3 = Person("Ritesh")

print("Total Person :", Person.total_person())
# Out:
# Total Person : 3

# %% [markdown]
# #9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator} / {self.denominator}"

f1 = Fraction(100, 4)
f2 = Fraction(200,5)

print(f1)
print(f2)
# Out:
# 100 / 4
# 200 / 5

# %% [markdown]
# #10.  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def __add__(self, other):
    return Vector(self.x + other.x, self.y + other.y)

  def __str__(self):
    return f"({self.x}, {self.y})"

v1 = Vector(10,2)
v2 = Vector(2,4)
v3 = v1 + v2
print(v3)
# Out:
# (12, 6)

# %% [markdown]
# #11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old")

p1 = Person("Priyanka" , 26)
p1.greet()
# Out:
# Hello, my name is Priyanka and I am 26 years old

# %% [markdown]
# #12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades

# %%
class Student:
  def __init__(self, name, grade):
    self.name = name
    self.grade = grade

  def average_grade(self):
    return sum(self.grade) / len(self.grade)


s1 = Student("Priyanka", [90,80,94])

print(f"{s1.name}'s average grade : {s1.average_grade()}")
# Out:
# Priyanka's average grade : 88.0

# %% [markdown]
# #13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
  def __init__(self):
    self.length = 0
    self.width = 0

  def set_dimensions(self, length, width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width

r1 = Rectangle()
r1.set_dimensions(10,50)
r1.area()
# Out:
# 500

# %% [markdown]
# #14.  Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
  def __init__(self, hours_worked, hourly_rate):
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
  def __init__(self, hours_worked, hourly_rate, bonus):
    super().__init__(hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    base_salary = super().calculate_salary()
    return base_salary + self.bonus

e = Employee(10000, 5000000)
e.calculate_salary()
# Out:
# 50000000000

# %% [markdown]
# #15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

p1 = Product("Laptop",45000,1)
print(f"{p1.name} total price: {p1.total_price()}")
# Out:
# Laptop total price: 45000

# %% [markdown]
# #16. . Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
class Animal:
  def sound(self):
    print("Animal's make sound")

class Cow(Animal):
  def sound(self):
    print("Cow makes the sound 'moo'")

class Sheep(Animal):
  def sound(self):
    print("Sheep makes the sound 'Meeh'")

ani = Animal()
ani.sound()
# Out:
# Animal's make sound

# %%
ani1 = Cow()
ani1.sound()
# Out:
# Cow makes the sound 'moo'

# %%
ani2 = Sheep()
ani2.sound()
# Out:
# Sheep makes the sound 'Meeh'

# %% [markdown]
# #17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

# %%
class Book:
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"{self.title} by {self.author} published in the year {self.year_published}"

book = Book("Atomic Habits", "James Clear", 2018)
book.get_book_info()
# Out:
# 'Atomic Habits by James Clear published in the year 2018'

# %% [markdown]
# #18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
   super().__init__(address , price)
   self.number_of_rooms = number_of_rooms

mansion = Mansion("123 Mackenzi Street", 50000000, 15)
print(f"{mansion.address} is auctioned at {mansion.price} and has {mansion.number_of_rooms} rooms") # Corrected print statement for Mansion object
# Out:
# 123 Mackenzi Street is auctioned at 50000000 and has 15 rooms
