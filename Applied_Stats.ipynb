# %% [markdown]
# #Q1. What are Type I and Type II errors in hypothesis testing, and how do they impact decision-making?
#
# 1. **Type I error** : is when we reject the null hypothesis or fail to accept null  hypothesis, when it is true. Eg - An innocent person is charged for a crime, and in the court he is convicted.It leads to faalse alarms or unnecessary actions.It is denoted  by alpha
#
# 2. **Type II error** : is when , we fail to reject the null hypothesis, when it is actually false. Eg - a guilty person may not be convicted. It is denoted by beta.
#
# **Impact on decision making** -
#
# a. Choosing the right significance level helps balance both the errors.
#
# b. Lower alpha, reduces the chance of type I errors buut increases the chance of type II errors.
#
# #Q2. :What is the P-value in hypothesis testing, and how should it be interpreted in the context of the null hypothesis?
#
# P-value is the  probability value calculated from a statistics test. In hypothesis testing  it is used to decide, whether to accept or to reject the null hypothesis.
# If p-values is less than the calculated statistics, then we failto accept the null hypothesis, and if the p-value is more than the calculated statistics, we fail  to reject the null hypothesis
#
# #Q3. Explain the difference between a Z-test and a T-test, including when to use each.
#
# **Z - Test** - is used when the population size  is more > 30 and when the population variance (σ²)is known. If Z (critical) is more than Z(stats), we accept the null hypothesis.
# Here Z-table is used to calculate Zcritical value
#
# **Formula** ---> Z = Xˉ− μ / σ /√n
# X bar = sample mean
# μ = population mean
# σ = population standard deviation
# √n = sample size
#
# **T- test** - is used when population size is < 30 and the sample standard deviation is known, but population standard deviation is not known. Here t-table is  used to calculate T critical.
#
# **Formula** ----> t = Xˉ− μ / s /√n
# X bar = sample mean
# μ = population mean
# s = sample standard deviation
# √n = sample size

# %% [markdown]
# #Q4. What is a confidence interval, and how does the margin of error influence its width and interpretation?
#
# Confidence interval gives a range of possible values for an unknown population parameter, based on a sample data. It shows that how confidence we are that the true population lies within that range.
#
# **Formula** ---> CI = Xˉ+- Zα/2 x σ / √n
#
# X bar = sample mean
# Zα/2 = critical value
# σ = standard deviation
# √n = sample size.
#
# **Interpretation** - A 95% confidence interval means that  if we took many random samples and built in   intervals each time, about 95% of those intervals would contain the true population mean.
#
# **Margin of Error** -
# It is the amount added and subtracted from the point estimate to create the confidence interval.
#
#
# #Q5. Describe the purpose and assumptions of an ANOVA test. How does it extend hypothesis testing to more than two groups?
#
# ANOVA is analysis of variance. It is a statistical test used to compare the means of three  or more groups to see if at least one group mean is significantly different from the others. Example - A researcher wants to test if three diets(A, B, C) lead to different average weight losses. ANOVA checks if the mean weight loss is the same for all diets or not.
# ANOVA compares two  types of variation. One is between group variance and other is within group variance.
#
# #Q6. Write a Python program to perform a one-sample Z-test and interpret the result for a given dataset.
#
# Suppose, a child pyscologist wants to determine the avg time, working  mothers talking to thier children is upto 11 mins. Here sample mean = 11.5 mins, population mean = 11 mins. standard deviation (σ) = 2.3 mins and n = 100 and LOS = 5%

# %%
from math import sqrt
from scipy.stats import norm

sample_mean = 11.5
population_mean = 11
population_std = 2.3
n = 100
Z_critical = 2.17

z = (sample_mean - population_mean) / (population_std / sqrt(n))
print(z)
if Z_critical < 0.05 :
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis, or null hypothesis will be accepted")
# Out:
# 2.173913043478261
# Fail to reject the null hypothesis, or null hypothesis will be accepted

# %% [markdown]
# #Q7. Simulate a dataset from a binomial distribution (n = 10, p = 0.5) using NumPy and plot the histogram.
#
# Number of trials = 10
# Probability of success = 0.5
# Number of samples = 1000

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.05
size =1000

data  = np.random.binomial(n, p, size)
plt.hist(data, bins=range(n+2), edgecolor="blue", alpha=0.7)
plt.title("Binomial Distribution")
plt.xlabel("Number of successes")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #Q8. Generate multiple samples from a non-normal distribution and implement the Central Limit Theorem using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.random.exponential(scale=2, size=100000)  # mean=2

sample_size = 50   # number of observations per sample
num_samples = 1000  # number of samples

sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

plt.figure(figsize=(12,5))

# Plot population distribution
plt.subplot(1, 2, 1)
plt.hist(population, bins=40, color='skyblue', edgecolor='black')
plt.title('Original Non-Normal Distribution (Exponential)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot sampling distribution of means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=40, color='lightgreen', edgecolor='black')
plt.title(f'Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Q9. Write a Python function to calculate and visualize the confidence interval for a sample mean.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate and visualize the confidence interval for a sample mean.

    Parameters:
        data (array-like): Sample data
        confidence (float): Confidence level (default 0.95)
    """

    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)  # Standard error of mean

    t_value = stats.t.ppf((1 + confidence) / 2, df=n-1)
    margin_of_error = t_value * std_err


    lower = mean - margin_of_error
    upper = mean + margin_of_error


    print(f"Sample Mean: {mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval: ({lower:.2f}, {upper:.2f})")

    plt.figure(figsize=(8, 4))
    plt.hist(data, bins=20, color='lightblue', edgecolor='black', alpha=0.7)
    plt.axvline(mean, color='red', linestyle='--', label=f"Mean = {mean:.2f}")
    plt.axvline(lower, color='green', linestyle='--', label=f"Lower CI = {lower:.2f}")
    plt.axvline(upper, color='green', linestyle='--', label=f"Upper CI = {upper:.2f}")
    plt.title(f"{int(confidence*100)}% Confidence Interval for Sample Mean")
    plt.xlabel("Sample Values")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=30)
confidence_interval(sample_data, confidence=0.95)
# Out:
# Sample Mean: 48.12
# 95% Confidence Interval: (44.76, 51.48)

# %% [markdown]
# #Q10.  Perform a Chi-square goodness-of-fit test using Python to compare observed and expected distributions, and explain the outcome.

# %%
import numpy as np
from scipy.stats import chisquare
import matplotlib.pyplot as plt

observed = np.array([8, 9, 10, 11, 12, 10])  # observed counts for faces 1–6


expected = np.array([10, 10, 10, 10, 10, 10])  # equal expected frequency (60 rolls / 6 faces)


chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square Statistic: {chi_stat:.3f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("❌ Reject the null hypothesis — the distribution does NOT fit (die may be biased).")
else:
    print("✅ Fail to reject the null hypothesis — the distribution fits well (die is fair).")


faces = np.arange(1, 7)
plt.bar(faces - 0.2, observed, width=0.4, label='Observed', color='skyblue', edgecolor='black')
plt.bar(faces + 0.2, expected, width=0.4, label='Expected', color='lightgreen', edgecolor='black')
plt.xlabel('Die Face')
plt.ylabel('Frequency')
plt.title('Chi-square Goodness-of-Fit: Observed vs Expected')
plt.legend()
plt.show()
# Out:
# Chi-square Statistic: 1.000
# P-value: 0.9626
# ✅ Fail to reject the null hypothesis — the distribution fits well (die is fair).
